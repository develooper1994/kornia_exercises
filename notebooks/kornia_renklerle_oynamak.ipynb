# %%
from matplotlib import pyplot as plt
import cv2
import numpy as np

import torch
import kornia
import torchvision

def imshow(input):
    out = torchvision.utils.make_grid(input, nrow=2, padding=1)
    out_np = kornia.tensor_to_image(out)
    plt.imshow(out_np)
    plt.axis("off")

# %%
img_bgr = cv2.imread("../KendiResmim.jpg", cv2.IMREAD_COLOR)
print(img_bgr.shape)
# Out:
# (1198, 1198, 3)

# %%
x_bgr = kornia.image_to_tensor(img_bgr, keepdim=False)
print(x_bgr.shape)
# Out:
# torch.Size([1, 3, 1198, 1198])

# %%
x_bgr = kornia.image_to_tensor(img_bgr)
x_rgb = kornia.bgr_to_rgb(x_bgr)
print(x_rgb.shape)
# Out:
# torch.Size([3, 1198, 1198])

# %% [markdown]
# Create batch and normalize

# %%
x_rgb = x_rgb.expand(4, -1, -1, -1)
x_rgb = x_rgb.float() / 255.0
print(x_rgb.shape)

imshow(x_rgb)
# Out:
# torch.Size([4, 3, 1198, 1198])

# %% [markdown]
# Adjust Brightness

# %%
x_brightness = kornia.adjust_brightness(x_rgb, 0.6)
print(x_brightness.shape)
imshow(x_brightness)
# Out:
# torch.Size([4, 3, 1198, 1198])

# %% [markdown]
# Adjust Contrast

# %%
x_contrast = kornia.adjust_contrast(x_rgb, 0.2)
print(x_contrast.shape)
imshow(x_contrast)
# Out:
# torch.Size([4, 3, 1198, 1198])

# %% [markdown]
# Adjust Gamma

# %%
x_gamma = kornia.adjust_gamma(x_rgb, gamma=3.0, gain=1.5)
print(x_gamma.shape)
imshow(x_gamma)
# Out:
# torch.Size([4, 3, 1198, 1198])

# %% [markdown]
# Adjust Saturation

# %%
x_saturation = kornia.adjust_saturation(x_rgb, 0.2)
print(x_saturation.shape)
imshow(x_brightness)
# Out:
# torch.Size([4, 3, 1198, 1198])

# %% [markdown]
# Adjust Hue

# %%
x_hue = kornia.adjust_hue(x_rgb, 0.5)
print(x_hue.shape)
imshow(x_hue)
# Out:
# torch.Size([4, 3, 1198, 1198])
